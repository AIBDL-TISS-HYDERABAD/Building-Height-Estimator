# %% [markdown]
# # Building Height Estimator (CNN Regression Model)
# <hr/>
#
# Centre Name: **TBD** <br>
# Institute Number: **Tata Institute of Social Sciences, Hyderabad Campus** <br>
# Creators: **Dr. Dipak Samal and Raunit Singh** <br>
# <hr/>

# %% [markdown]
# ## Project  Overview
# ### Objectives
#
# 1. **Data Collection**: Gather data of builing footprints and building heights
#
# 1. **Data Preprocessing**: Clean and preprocess the collected data to make it suitable for model training.
#
# 1. **Model Development**: Develop a regression model using appropriate machine learning algorithms. The model should be able to predict the height of a building based on the selected features.
#
# 1. **Model Evaluation**: Evaluate the performance of the model using suitable metrics. This will help in understanding the accuracy of the model and its ability to generalize on unseen data.
#
# 1. **Documentation**: Document all the steps, methodologies, and findings of the project. This will serve as a reference for future projects and for stakeholders to understand the work done.
#
# 1. **Future Scope**: Identify areas for future improvement and expansion of the project. This could include incorporating additional features, refining the model, or adapting the model to predict other building characteristics.

# %% [markdown]
# ### Problem Defination
# Sure, here's the problem definition for your project:
#
# - **Problem**: The height of buildings is a crucial factor in urban planning, disaster management, and real estate valuation. However, obtaining accurate and up-to-date information about building heights can be challenging and time-consuming.
#
# - **Proposed Solution**: The project aims to develop a Building Height Regression Model that can predict the height of a building based on two parameters building footprint and a satellite image of an area around the building. This model will serve as a tool to estimate building heights quickly and accurately, thereby aiding in efficient urban planning and development.
#
# - **Data Requirements**: The model will require data related to buildings, [Microfost Building Footprint Training Data with Heights](https://hub.arcgis.com/datasets/esri::microsoft-buildings-footprint-training-data-with-heights-/about)! and Satellite imagary.
#
# - **Expected Outcome**: The successful development of a regression model that can accurately predict building heights. This model will be a valuable tool for stakeholders such as urban planners, disaster management authorities, and real estate developers.
#
# - **Future Scope**: The model developed through this project could be further refined or expanded to include additional features or to predict other building characteristics, thereby increasing its utility and applicability in the field of urban planning and development.

# %% [markdown]
# ### Approach
#
# 1. **Data Collection**: Gather data related to buildings. Collect images of buildings from various angles and under different lighting conditions.
#
# 2. **Data Preprocessing**: Preprocess the data to make it suitable for training the CNN by resizing the images, normalizing the pixel values, and augmenting the dataset with transformations like rotation and flipping.
#
# 3. **Model Architecture**: Design the architecture of the CNN. This typically involves specifying the number and types of layers in the network. THe model will start with several convolutional and pooling layers to extract features from the images, followed by fully connected layers to make the final prediction.
#
# 4. **Model Training**: Train the CNN on the preprocessed data. This involves feeding the data through the network, comparing the network's predictions to the true values using a loss function, and updating the network's weights using an optimization algorithm to minimize the loss.
#
# 5. **Model Evaluation**: Evaluate the performance of the trained CNN on a separate test set. This involves measuring how well the network's predictions match the true values using metrics such as Root Mean Squared Error (RMSE).
#
# 6. **Model Optimization**: If the performance of the CNN is not satisfactory, adjust the model's architecture or training procedure and repeat steps 4 and 5. This could involve changing the number of layers or neurons in the network, adjusting the learning rate of the optimization algorithm, or increasing the amount of training data.
#
# 7. **Model Deployment**: Once the CNN performs satisfactorily, deploy the model for use in predicting building heights. This involves saving the trained model and writing a function or API that takes in the necessary input data and returns the predicted building height.

# %% [markdown]
# ### Sections
# 1. Project Overview
# 1. Libraries
#     1. Geopandas
#     1. Shapely
#     1. Pnadas
#     1. Seaborn
#     1. Matplotlib
#     1. os
#     1. TensorFlow
#     1. Keras
#     1. Scikit-learn
#
# 1. Importing and cleaning Geodata
# 1. EDA
# 1. Model Development
# 1. Model Training
# 1. Model Testing

# %% [markdown]
# ### Libraries

# %% [markdown]
# #### Importing the Libraries

# %%
import geopandas as gpd
from shapely.geometry import Polygon
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import os
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.metrics import R2Score
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\rauni\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# TensorFlow version: 2.14.0

# %% [markdown]
# ### Importing and Gcleaning Geodata

# %% [markdown]
# #### Importing the Geodata

# %%
shp=gpd.read_file("GeoData/Sample.shp")

# %%
shp
# Out:
#         OBJECTID  Height  Shape__Are  Shape__Len  \
# 0        4441376   15.94  729.878906  116.767869
# 1        4441377   16.99  414.535156   88.556755
# 2        4441378   15.38  343.570312   80.852324
# 3        4441379   15.08  255.242188   64.684945
# 4        4441380   21.13  754.343750  112.173641
# ...          ...     ...         ...         ...
# 433265   5579765   20.48  139.128906   55.220550
# 433266   5579766   23.86  321.769531   72.188952
# 433267   5579767   10.35  128.324219   45.528611
# 433268   5579768   12.35  533.003906   96.557174
# 433269   5579769   13.41  228.718750   63.303112
#
#                                                  geometry
# 0       POLYGON Z ((-93.30352 44.96674 0.00000, -93.30...
# 1       POLYGON Z ((-93.30376 44.96696 0.00000, -93.30...
# 2       POLYGON Z ((-93.30369 44.96718 0.00000, -93.30...
# 3       POLYGON Z ((-93.30352 44.96732 0.00000, -93.30...
# 4       POLYGON Z ((-93.30351 44.96778 0.00000, -93.30...
# ...                                                   ...
# 433265  POLYGON Z ((-74.01515 40.69322 0.00000, -74.01...
# 433266  POLYGON Z ((-74.02200 40.68519 0.00000, -74.02...
# 433267  POLYGON Z ((-74.02181 40.68504 0.00000, -74.02...
# 433268  POLYGON Z ((-74.02424 40.68456 0.00000, -74.02...
# 433269  POLYGON Z ((-74.02476 40.68444 0.00000, -74.02...
#
# [433270 rows x 5 columns]

# %% [markdown]
# #### Reorganizing data as per model requirements

# %%
df = shp[['OBJECTID','Height']].copy()
df
# Out:
#         OBJECTID  Height
# 0        4441376   15.94
# 1        4441377   16.99
# 2        4441378   15.38
# 3        4441379   15.08
# 4        4441380   21.13
# ...          ...     ...
# 433265   5579765   20.48
# 433266   5579766   23.86
# 433267   5579767   10.35
# 433268   5579768   12.35
# 433269   5579769   13.41
#
# [433270 rows x 2 columns]

# %%
import os
image_dir = 'final_imgs/'
image_files = os.listdir(image_dir)

df['image_path'] = ''
for index, row in df.iterrows():
    idno = row['OBJECTID']
    image_name = f'IMG-{idno}.png'
    if image_name in image_files:
        df.loc[index, 'image_path'] = os.path.join(image_dir, image_name)
fdf = df[df['image_path'] != ''].reset_index(drop=True)

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df
fdf = swap_columns(fdf,"Height","image_path")
fdf
# Out:
#        OBJECTID                  image_path  Height
# 0       2768014  final_imgs/IMG-2768014.png   19.59
# 1       2768015  final_imgs/IMG-2768015.png   15.47
# 2       2768016  final_imgs/IMG-2768016.png    8.25
# 3       2768017  final_imgs/IMG-2768017.png   10.05
# 4       2768018  final_imgs/IMG-2768018.png   12.68
# ...         ...                         ...     ...
# 13559   5579763  final_imgs/IMG-5579763.png   11.26
# 13560   5579764  final_imgs/IMG-5579764.png   20.51
# 13561   5579765  final_imgs/IMG-5579765.png   20.48
# 13562   5579768  final_imgs/IMG-5579768.png   12.35
# 13563   5579769  final_imgs/IMG-5579769.png   13.41
#
# [13564 rows x 3 columns]

# %%
fdf=fdf.drop(['OBJECTID'],axis=1)
fdf
# Out:
#                        image_path  Height
# 0      final_imgs/IMG-2768014.png   19.59
# 1      final_imgs/IMG-2768015.png   15.47
# 2      final_imgs/IMG-2768016.png    8.25
# 3      final_imgs/IMG-2768017.png   10.05
# 4      final_imgs/IMG-2768018.png   12.68
# ...                           ...     ...
# 13559  final_imgs/IMG-5579763.png   11.26
# 13560  final_imgs/IMG-5579764.png   20.51
# 13561  final_imgs/IMG-5579765.png   20.48
# 13562  final_imgs/IMG-5579768.png   12.35
# 13563  final_imgs/IMG-5579769.png   13.41
#
# [13564 rows x 2 columns]

# %%
# folder_path = 'Augmented_Images'
# x=os.listdir(folder_path)
# l=[]
# for i in x:
#     original_name = i.split('_')[0]
#     l.append(original_name)
# x=set(l)
# x.remove('Augmented')
# len(x)
# Out:
# 8731

# %%
# l2=[]
# for i in df1['image_path']:
#     a = i.split('/')[1]
#     b=a.split('.')[0]
#     l2.append(b)

# %%
# x = {item for item in x if item not in l2}

# len(x)
# Out:
# 8680

# %%
# len(fdf)
# Out:
# 13564

# %%
# bdf
# Out:
#                        image_path  Height
# 0      final_imgs/IMG-2768014.png   19.59
# 3      final_imgs/IMG-2768017.png   10.05
# 7      final_imgs/IMG-2768021.png    8.42
# 8      final_imgs/IMG-2768022.png    9.95
# 12     final_imgs/IMG-2768026.png   10.85
# ...                           ...     ...
# 13551  final_imgs/IMG-5363455.png   15.58
# 13560  final_imgs/IMG-5579764.png   20.51
# 13561  final_imgs/IMG-5579765.png   20.48
# 13562  final_imgs/IMG-5579768.png   12.35
# 13563  final_imgs/IMG-5579769.png   13.41
#
# [4884 rows x 2 columns]

# %%
# test_df, validation_df = train_test_split(bdf, test_size=0.45, random_state=42)
# print(len(test_df))
# print(len(validation_df))
# Out:
# 2686
# 2198

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Checking Height Destribution

# %%
fdf['Height'].describe()
# Out:
# count    13564.000000
# mean        27.661351
# std         34.923312
# min          4.010000
# 25%         12.650000
# 50%         16.760000
# 75%         22.120000
# max        440.550000
# Name: Height, dtype: float64

# %%
bins = np.arange(0, fdf['Height'].max() + 100, 100)
plt.figure(figsize=(10, 6))
sns.histplot(data=fdf, x="Height", bins=bins)
plt.title('Histogram of Heights')
plt.show()

# %% [markdown]
# #### Splitting data into training and testing

# %%
train_df, test_df = train_test_split(fdf, test_size=0.20, random_state=42)

# %%
train_df
# Out:
#                        image_path  Height
# 5725   final_imgs/IMG-5656837.png   15.84
# 6149   final_imgs/IMG-5660437.png   20.47
# 11319  final_imgs/IMG-5313827.png  102.18
# 11936  final_imgs/IMG-5324548.png   21.25
# 2546   final_imgs/IMG-5635237.png   19.49
# ...                           ...     ...
# 5191   final_imgs/IMG-5653569.png   13.00
# 13418  final_imgs/IMG-5362715.png   18.28
# 5390   final_imgs/IMG-5655058.png   18.02
# 860    final_imgs/IMG-2838015.png   11.17
# 7270   final_imgs/IMG-5698520.png   16.84
#
# [10851 rows x 2 columns]

# %% [markdown]
# #### splitting data into Training and Validation

# %%
train_df, validation_df = train_test_split(train_df, test_size=0.20, random_state=42)

# %%
train_df
# Out:
#                        image_path  Height
# 11551  final_imgs/IMG-5316281.png   44.48
# 132    final_imgs/IMG-2771642.png   11.72
# 404    final_imgs/IMG-2821984.png   11.78
# 7117   final_imgs/IMG-5694403.png   35.87
# 7736   final_imgs/IMG-5724121.png   32.88
# ...                           ...     ...
# 5847   final_imgs/IMG-5656959.png   11.31
# 12927  final_imgs/IMG-5354718.png   17.82
# 6827   final_imgs/IMG-5679398.png   18.35
# 1523   final_imgs/IMG-2842904.png   11.14
# 3331   final_imgs/IMG-5641744.png   22.83
#
# [6944 rows x 2 columns]

# %% [markdown]
# #### Importing Big Buildings data
# Big Buildings data consits of satelitte images of about 50 buildings above 300m in height

# %%
df1=pd.read_csv('Big_Buildings.csv')
df1
# Out:
#                     image_path      Height
# 0   final_imgs/IMG-8067493.png  587.400000
# 1   final_imgs/IMG-8067477.png  739.400000
# 2   final_imgs/IMG-8067476.png  530.000000
# 3   final_imgs/IMG-8067481.png  530.000000
# 4   final_imgs/IMG-8067478.png  530.000000
# 5   final_imgs/IMG-8067479.png  562.000000
# 6   final_imgs/IMG-8067480.png  520.910000
# 7   final_imgs/IMG-8067482.png  497.600000
# 8   final_imgs/IMG-8067483.png  479.830000
# 9   final_imgs/IMG-8067484.png  449.200000
# 10  final_imgs/IMG-8067485.png  401.100000
# 11  final_imgs/IMG-8067486.png  378.500000
# 12  final_imgs/IMG-8067487.png  371.000000
# 13  final_imgs/IMG-8067488.png  368.000000
# 14  final_imgs/IMG-8067489.png  347.509000
# 15  final_imgs/IMG-8067490.png  339.000000
# 16  final_imgs/IMG-8067491.png  328.000000
# 17  final_imgs/IMG-8067492.png  321.000000
# 18  final_imgs/IMG-8067494.png  318.000000
# 19  final_imgs/IMG-8067495.png  315.000000
# 20  final_imgs/IMG-8067496.png  315.000000
# 21  final_imgs/IMG-8067498.png  310.000000
# 22  final_imgs/IMG-8067497.png  309.909000
# 23  final_imgs/IMG-8067499.png  304.000000
# 24  final_imgs/IMG-8067500.png  301.000000
# 25  final_imgs/IMG-8067501.png  357.808000
# 26  final_imgs/IMG-8067502.png  346.250900
# 27  final_imgs/IMG-8067503.png  343.500000
# 28  final_imgs/IMG-8067504.png  472.440000
# 29  final_imgs/IMG-8067505.png  310.300000
# 30  final_imgs/IMG-8067506.png  442.140003
# 31  final_imgs/IMG-8067507.png  634.000000
# 32  final_imgs/IMG-8067508.png  357.000000
# 33  final_imgs/IMG-8067509.png  383.000000
# 34  final_imgs/IMG-8067510.png  392.000000
# 35  final_imgs/IMG-8067511.png  392.800000
# 36  final_imgs/IMG-8067512.png  342.100000
# 37  final_imgs/IMG-8067513.png  352.300000
# 38  final_imgs/IMG-8067514.png  319.900000
# 39  final_imgs/IMG-8067515.png  380.500000
# 40  final_imgs/IMG-8067516.png  322.500000
# 41  final_imgs/IMG-8067517.png  351.500000
# 42  final_imgs/IMG-8067518.png  306.360000
# 43  final_imgs/IMG-8067519.png  276.200000
# 44  final_imgs/IMG-8067520.png  355.400000
# 45  final_imgs/IMG-8067521.png  300.100000
# 46  final_imgs/IMG-8067522.png  310.500000
# 47  final_imgs/IMG-8067523.png  360.100000
# 48  final_imgs/IMG-8067524.png  345.000000
# 49  final_imgs/IMG-8067525.png  528.000000
# 50  final_imgs/IMG-8067526.png  234.000000

# %% [markdown]
# #### Checking Distribution of big buildings data

# %%
bins = np.arange(0, df1['Height'].max() + 100, 100)
plt.figure(figsize=(10, 6))
sns.histplot(data=df1, x="Height", bins=bins)
plt.title('Histogram of Heights')
plt.show()

# %% [markdown]
# #### Merging big buildings data with training data

# %%
train_df=pd.concat([train_df, df1], ignore_index=True)
train_df=train_df.sample(frac = 1)
train_df
# Out:
#                       image_path  Height
# 7234  final_imgs/IMG-5342033.png   21.50
# 6163  final_imgs/IMG-2768030.png   16.50
# 4686  final_imgs/IMG-1093968.png   20.32
# 6203  final_imgs/IMG-5308742.png   62.53
# 7985  final_imgs/IMG-5342192.png    8.85
# ...                          ...     ...
# 3072  final_imgs/IMG-5646963.png   31.64
# 463   final_imgs/IMG-2846408.png   15.35
# 3750  final_imgs/IMG-1095061.png   18.11
# 1264  final_imgs/IMG-5645538.png   16.38
# 4464  final_imgs/IMG-2844483.png    8.26
#
# [8731 rows x 2 columns]

# %% [markdown]
# #### Making sure augmentation folder is empty

# %%
folder_path = 'Augmented_Images'
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path) 
        elif os.path.isdir(file_path):
            os.rmdir(file_path) 
    except Exception as e:
        print(f'Failed to delete {file_path}. Reason: {e}')

# %% [markdown]
# #### Performing data augmentation on data to increase the volume of the data

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=300,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)
for index, row in train_df.iterrows():
    img = Image.open(row['image_path'])
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)
    
    original_name = os.path.splitext(os.path.basename(row['image_path']))[0]
    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir='Augmented_Images', save_prefix=original_name+'_', 
                              save_format='png'):
        i += 1
        if i > 20:
            break

# %%
new_images = os.listdir('Augmented_Images')
for image in new_images:
    original_name = image.split('_')[0]
    original_height = df1[df1['image_path'].str.contains(original_name)]['Height'].values[0]
    df1 = df1.append({'image_path': 'Augmented_Images/' + image, 'Height': original_height}, 
                     ignore_index=True)

df.to_csv('Augmented_Images/Augmented_Images.csv', index=False)

# %% [markdown]
# #### Importing Augmented Big Buildings data

# %%
train_df=pd.read_csv('Augmented_Images/Augmented_Images.csv')
train_df=train_df.sample(frac = 1)
train_df
# Out:
#                                       image_path  Height
# 178148  Augmented_Images/IMG-5693550__0_2272.png   78.27
# 67319   Augmented_Images/IMG-2842763__0_8377.png   12.00
# 106422    Augmented_Images/IMG-5355438__0_49.png    9.57
# 14393   Augmented_Images/IMG-1059651__0_8969.png   19.87
# 31603   Augmented_Images/IMG-1095293__0_9236.png   28.67
# ...                                          ...     ...
# 54799   Augmented_Images/IMG-2827716__0_1729.png    9.56
# 184499  Augmented_Images/IMG-5717227__0_7668.png   33.40
# 31109   Augmented_Images/IMG-1095172__0_4358.png   21.01
# 152161  Augmented_Images/IMG-5653563__0_5834.png   15.59
# 142585   Augmented_Images/IMG-5647296__0_449.png   17.61
#
# [191910 rows x 2 columns]

# %% [markdown]
# #### EDA of Training Data

# %%
train_df['Height'].describe()
# Out:
# count    191910.000000
# mean         29.673600
# std          44.581669
# min           4.010000
# 25%          12.720000
# 50%          16.850000
# 75%          22.230000
# max         739.400000
# Name: Height, dtype: float64

# %%
bins = np.arange(0, train_df['Height'].max() + 100, 100)
plt.figure(figsize=(10, 6))
sns.histplot(data=train_df, x="Height", bins=bins)
plt.title('Histogram of Heights')
plt.show()

# %% [markdown]
# ### Model Devlopment

# %% [markdown]
# #### Creating Image Data Generators

# %%
train_generator = ImageDataGenerator(rescale=1./255)
vali_generator = ImageDataGenerator(rescale=1./255)
test_generator  = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# #### Loading Image from Dataframe

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col="image_path",
    y_col="Height",
    batch_size=32,
    seed=42,
    shuffle=True,
    color_mode="rgb",
    class_mode="raw",
    target_size=(256,256)
)

Validation_images = vali_generator.flow_from_dataframe(
    dataframe=validation_df,
    x_col="image_path",
    y_col="Height",
    batch_size=32,
    seed=42,
    shuffle=True,
    color_mode="rgb",
    class_mode="raw",
    target_size=(256,256)
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col="image_path",
    y_col="Height",
    batch_size=32,
    shuffle=False,
    color_mode="rgb",
    class_mode="raw",
    target_size=(256,256)
)
# Out:
# Found 191910 validated image filenames.
# Found 2198 validated image filenames.
# Found 2686 validated image filenames.

# %% [markdown]
# #### Preview of Images

# %%
images, _ = next(train_images)
for i in range(9):
    plt.subplot(330 + 1 + i)
    plt.imshow(images[i])
plt.show()

# %% [markdown]
# #### Defining Model Arcitecture

# %%
inputs = tf.keras.Input(shape=(256,256,3))
x = tf.keras.layers.Conv2D(16, kernel_size=(3,3), activation='relu')(inputs)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs,outputs=outputs)

# %% [markdown]
# #### Explaining the model architecture

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 48545 (189.63 KB)
# Trainable params: 48545 (189.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Load an image
image = Image.open('final_imgs/IMG-1046439.png')
image = np.array(image) / 255.0

# Add an extra dimension
image = np.expand_dims(image, axis=0)

# Ensure the image tensor is on the same device as the model
image = tf.convert_to_tensor(image)

# Define a new model for each layer that will return the feature maps
layer_names = [layer.name for layer in model.layers if 'conv' in layer.name or 'pooling' in layer.name]
layer_outputs = [model.get_layer(name).output for name in layer_names]
feature_model = tf.keras.Model(inputs=model.inputs, outputs=layer_outputs)

# Generate the feature maps
feature_maps = feature_model.predict(image)
# Plot the feature maps
for layer_name, fmap in zip(layer_names, feature_maps):
    print(f"Feature maps for layer: {layer_name}")
    if len(fmap.shape) == 4:
        for i in range(fmap.shape[-1]):
            plt.subplot(8, 8, i+1)
            plt.imshow(fmap[0, :, :, i], cmap='viridis')
            plt.axis('off')
        plt.show()
    else:
        print("The feature map for this layer is not 4-dimensional, so it cannot be plotted as an image.")
        if len(fmap.shape) == 2:
            if 'dense' in layer_name:
                plt.figure(figsize=(10, 5))
                plt.bar(range(fmap.shape[1]), fmap[0])
                plt.title(f"Dense layer output for layer: {layer_name}")
                plt.show()
            else:
                plt.figure(figsize=(10, 5))
                plt.bar(range(fmap.shape[1]), fmap[0])
                plt.title(f"Global Average Pooling output for layer: {layer_name}")
                plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026AD6EC8430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 168ms/step
# Feature maps for layer: conv2d
# Feature maps for layer: max_pooling2d
# Feature maps for layer: conv2d_1
# Feature maps for layer: max_pooling2d_1
# Feature maps for layer: conv2d_2
# Feature maps for layer: max_pooling2d_2
# Feature maps for layer: global_average_pooling2d
# The feature map for this layer is not 4-dimensional, so it cannot be plotted as an image.

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Training the Model

# %%
model.compile(
    optimizer = 'adam',
    loss = 'mse',
    metrics=[R2Score()]
)

history = model.fit(
    train_images,
    validation_data = Validation_images,
    epochs = 100,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=6,
            verbose=1,
            restore_best_weights = True
        )
    ]
)
# Out:
# Epoch 1/100
# 5998/5998 [==============================] - 3847s 641ms/step - loss: 1432.5111 - r2_score: 0.2792 - val_loss: 944.3738 - val_r2_score: 0.3410
# Epoch 2/100
# 5998/5998 [==============================] - 3843s 641ms/step - loss: 1132.3400 - r2_score: 0.4303 - val_loss: 834.6348 - val_r2_score: 0.4176
# Epoch 3/100
# 5998/5998 [==============================] - 3898s 650ms/step - loss: 930.2082 - r2_score: 0.5320 - val_loss: 812.6259 - val_r2_score: 0.4329
# Epoch 4/100
# 5998/5998 [==============================] - 3896s 650ms/step - loss: 789.5059 - r2_score: 0.6028 - val_loss: 580.6950 - val_r2_score: 0.5948
# Epoch 5/100
# 5998/5998 [==============================] - 3879s 647ms/step - loss: 695.4647 - r2_score: 0.6501 - val_loss: 556.9938 - val_r2_score: 0.6113
# Epoch 6/100
# 5998/5998 [==============================] - 3860s 643ms/step - loss: 631.2648 - r2_score: 0.6824 - val_loss: 570.4307 - val_r2_score: 0.6019
# Epoch 7/100
# 5998/5998 [==============================] - 3883s 647ms/step - loss: 591.2888 - r2_score: 0.7025 - val_loss: 608.7277 - val_r2_score: 0.5752
# Epoch 8/100
# 5998/5998 [==============================] - 3863s 644ms/step - loss: 559.8981 - r2_score: 0.7183 - val_loss: 672.8763 - val_r2_score: 0.5304
# Epoch 9/100
# 5998/5998 [==============================] - 3914s 652ms/step - loss: 533.7411 - r2_score: 0.7315 - val_loss: 576.3973 - val_r2_score: 0.5978
# Epoch 10/100
# 5998/5998 [==============================] - 5457s 910ms/step - loss: 504.6283 - r2_score: 0.7461 - val_loss: 719.8264 - val_r2_score: 0.4977
# Epoch 11/100
# 5998/5998 [==============================] - ETA: 0s - loss: 488.1481 - r2_score: 0.7544Restoring model weights from the end of the best epoch: 5.
# 5998/5998 [==============================] - 5470s 912ms/step - loss: 488.1481 - r2_score: 0.7544 - val_loss: 698.1494 - val_r2_score: 0.5128
# Epoch 11: early stopping

# %% [markdown]
# #### Checking Loss and Validation loss to make sure the model is not overfitting

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Time')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Checking Model Accuracy over time

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['r2_score'], label='Train')
plt.plot(history.history['val_r2_score'], label='Test')
plt.title('Model Accuracy Over Time')
plt.xlabel('Epochs')
plt.ylabel('R^2')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Testing

# %% [markdown]
# #### Testing The Model

# %%
predicted_heights = np.squeeze(model.predict(test_images))
true_heights = test_images.labels

mse = mean_squared_error(true_heights, predicted_heights)
rmse = np.sqrt(mse)

print("Test RMSE = {:.5f}".format(rmse))

r2 = r2_score(true_heights, predicted_heights)

print("Test R^2 = {:.5f}".format(r2))
# Out:
# 84/84 [==============================] - 31s 372ms/step
# Test RMSE = 22.66869
# Test R^2 = 0.58053

# %% [markdown]
# #### Checking Distribution of Errors

# %%
errors = true_heights - predicted_heights
plt.figure(figsize=(8, 6))
plt.hist(errors, bins=20, edgecolor='black')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %% [markdown]
# ### Checking Prediction Error

# %%
abs_errors = abs(errors)
pe = pd.DataFrame({
    'Predicted Heights (m)': predicted_heights,
    'Prediction Errors (m)': errors,
    'abs_errors': abs_errors
})
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Predicted Heights (m)', y='Prediction Errors (m)', hue='abs_errors', palette='rainbow', data=pe)
plt.title('Prediction Error Plot')
plt.hlines(0, predicted_heights.min(), predicted_heights.max(), colors='k', linestyles='dashed')

plt.show()

# %%
 cg = pd.DataFrame({
    'True Heights (m)': true_heights,
    'Predicted Heights (m)': predicted_heights,
    'abs_errors': abs_errors
})

plt.figure(figsize=(8, 6))
sns.scatterplot(x='True Heights (m)', y='Predicted Heights (m)', hue='abs_errors', palette='rainbow', data=cg)

plt.plot([true_heights.min(), true_heights.max()], [true_heights.min(), true_heights.max()], 'k--', lw=2)

plt.xlabel('True Heights (m)')
plt.ylabel('Predicted Heights (m)')
textstr = f'R² = {r2:.2f}\nRMSE = {rmse:.2f}'
plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, fontsize=14,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.show()

# %%
inputs = tf.keras.Input(shape=(256,256,3))
x = tf.keras.layers.Conv2D(16, kernel_size=(3,3), activation='relu')(inputs)
x = tf.keras.layers.AveragePooling2D()(x)
x = tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.AveragePooling2D()(x)
x = tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.AveragePooling2D()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs,outputs=outputs)

model.compile(
    optimizer = 'adam',
    loss = 'mse',
    metrics=[R2Score()]
)

history = model.fit(
    train_images,
    validation_data = Validation_images,
    epochs = 100,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=6,
            verbose=1,
            restore_best_weights = True
        )
    ]
)

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation Loss Over Time')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(10, 6))
# plt.plot(history.history['r2_score'], label='Train')
# plt.plot(history.history['val_r2_score'], label='Test')
# plt.title('Model Accuracy Over Time')
# plt.xlabel('Epochs')
# plt.ylabel('R^2')
# plt.legend()
# plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score
predicted_heights = np.squeeze(model.predict(test_images))
true_heights = test_images.labels

rmse3=np.sqrt(model.evaluate(test_images, verbose=0))

print("Test RMSE = {:.5f}".format(rmse3))

r23 = r2_score(true_heights,predicted_heights)

print("Test R^2 = {:.5f}".format(r23))

# %%
errors = true_heights - predicted_heights
plt.figure(figsize=(8, 6))
plt.hist(errors, bins=20, edgecolor='black')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
abs_errors = abs(errors)
pe = pd.DataFrame({
    'Predicted Heights (m)': predicted_heights,
    'Prediction Errors (m)': errors,
    'abs_errors': abs_errors
})
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Predicted Heights (m)', y='Prediction Errors (m)', hue='abs_errors', palette='rainbow', data=pe)
plt.title('Prediction Error Plot')
plt.hlines(0, predicted_heights.min(), predicted_heights.max(), colors='k', linestyles='dashed')

plt.show()

# %%
cg = pd.DataFrame({
    'True Heights (m)': true_heights,
    'Predicted Heights (m)': predicted_heights,
    'abs_errors': abs_errors
})

plt.figure(figsize=(8, 6))
sns.scatterplot(x='True Heights (m)', y='Predicted Heights (m)', hue='abs_errors', palette='rainbow', data=cg)

plt.plot([true_heights.min(), true_heights.max()], [true_heights.min(), true_heights.max()], 'k--', lw=2)

plt.xlabel('True Heights (m)')
plt.ylabel('Predicted Heights (m)')
textstr = f'R² = {r2:.2f}\nRMSE = {rmse:.2f}'
plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, fontsize=14,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.show()

# %%
model.summary()

# %%
inputs = tf.keras.Input(shape=(256,256,3))
x = tf.keras.layers.Conv2D(16, kernel_size=(3,3), activation='relu')(inputs)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs,outputs=outputs)

model.compile(
    optimizer = 'adam',
    loss = 'mse',
    metrics=[R2Score()]
)

history = model.fit(
    train_images,
    validation_data = Validation_images,
    epochs = 100,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            verbose=1,
            restore_best_weights = True
        )
    ]
)

# %%
model.summary()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Time')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['r2_score'], label='Train')
plt.plot(history.history['val_r2_score'], label='Test')
plt.title('Model Accuracy Over Time')
plt.xlabel('Epochs')
plt.ylabel('R^2')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score
predicted_heights = np.squeeze(model.predict(test_images))
true_heights = test_images.labels

rmse3=np.sqrt(model.evaluate(test_images, verbose=0))

print("Test RMSE = {:.5f}".format(rmse3))

r23 = r2_score(true_heights,predicted_heights)

print("Test R^2 = {:.5f}".format(r23))

# %%
errors = true_heights - predicted_heights
plt.figure(figsize=(8, 6))
plt.hist(errors, bins=20, edgecolor='black')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
abs_errors = abs(errors)
pe = pd.DataFrame({
    'Predicted Heights (m)': predicted_heights,
    'Prediction Errors (m)': errors,
    'abs_errors': abs_errors
})
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Predicted Heights (m)', y='Prediction Errors (m)', hue='abs_errors', palette='rainbow', data=pe)
plt.title('Prediction Error Plot')
plt.hlines(0, predicted_heights.min(), predicted_heights.max(), colors='k', linestyles='dashed')

plt.show()

# %%
cg = pd.DataFrame({
    'True Heights (m)': true_heights,
    'Predicted Heights (m)': predicted_heights,
    'abs_errors': abs_errors
})

plt.figure(figsize=(8, 6))
sns.scatterplot(x='True Heights (m)', y='Predicted Heights (m)', hue='abs_errors', palette='rainbow', data=cg)

plt.plot([true_heights.min(), true_heights.max()], [true_heights.min(), true_heights.max()], 'k--', lw=2)

plt.xlabel('True Heights (m)')
plt.ylabel('Predicted Heights (m)')
textstr = f'R² = {r2:.2f}\nRMSE = {rmse:.2f}'
plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, fontsize=14,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.show()
